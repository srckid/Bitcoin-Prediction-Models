# %%
import requests, pandas as pd, numpy as np
import requests
from pandas import DataFrame
from io import StringIO
import time, json
from datetime import date
from statsmodels.tsa.stattools import adfuller, acf, pacf
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.metrics import *
import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6

# %%
df = pd.read_csv('export_dataframe1.csv')
df.isnull().values.any()
# Out:
# False

# %%
df.head(10)
# Out:
#          time   close    high     low    open  volumefrom      volumeto  \
# 0  1465689600  666.55  683.85  592.79  591.60   217379.53  1.396846e+08
# 1  1465776000  700.07  718.24  652.78  666.55   216731.32  1.494425e+08
# 2  1465862400  685.14  702.52  654.69  700.07   135648.79  9.245835e+07
# 3  1465948800  690.77  695.07  670.45  685.14    78620.97  5.386357e+07
# 4  1466035200  761.21  769.73  687.43  690.77   229569.22  1.697046e+08
# 5  1466121600  743.90  771.89  704.21  761.21   215870.36  1.603024e+08
# 6  1466208000  753.77  776.04  727.13  743.90   120525.37  9.105699e+07
# 7  1466294400  761.04  765.10  740.38  753.77    60445.37  4.580598e+07
# 8  1466380800  733.97  764.60  717.41  761.04   112290.09  8.363762e+07
# 9  1466467200  667.38  732.23  626.05  733.97   248083.39  1.668284e+08
#
#    weighted_price
# 0        633.6975
# 1        684.4100
# 2        685.6050
# 3        685.3575
# 4        727.2850
# 5        745.3025
# 6        750.2100
# 7        755.0725
# 8        744.2550
# 9        689.9075

# %%
df['Date'] = pd.to_datetime(df['time'],unit='s').dt.date
group = df.groupby('Date')
Daily_Price = group['weighted_price'].mean()
Daily_Price.head()
# Out:
# Date
# 2016-06-12    633.6975
# 2016-06-13    684.4100
# 2016-06-14    685.6050
# 2016-06-15    685.3575
# 2016-06-16    727.2850
# Name: weighted_price, dtype: float64

# %%
# convert the date column into a time series with daily frequency

df['Date'] = pd.to_datetime(df['Date'])

# %%
indexed_df = df.set_index('Date')

# %%
ts = indexed_df['weighted_price']

# %%
ts.head()
# Out:
# Date
# 2016-06-12    633.6975
# 2016-06-13    684.4100
# 2016-06-14    685.6050
# 2016-06-15    685.3575
# 2016-06-16    727.2850
# Name: weighted_price, dtype: float64

# %%
# visualize the time series to see how Bitcoin changes over time
#Determing rolling statistics
rolmean = ts.rolling(window=5,center=False).mean() 
rolstd = ts.rolling(window=5,center=False).std()

#Plot rolling statistics:
orig = plt.plot(ts, color='green',label='Bitcoin Data')
mean = plt.plot(rolmean, color='red', label='Rolling Mean')
std = plt.plot(rolstd, color='black', label = 'Rolling Std')
plt.legend(loc='best')
plt.xlabel('Time(Days)',fontsize=24)
plt.ylabel('$(Dollar)',fontsize=24)
plt.title('Rolling Mean & Standard Deviation')
plt.show(block=False)

# %%
# resamply by week

ts_week = ts.resample('W').mean()

# %%
ts_week
# Out:
# Date
# 2016-06-12     633.697500
# 2016-06-19     719.034643
# 2016-06-26     658.359643
# 2016-07-03     657.849643
# 2016-07-10     656.407857
#                  ...
# 2020-06-28    9304.762143
# 2020-07-05    9128.255000
# 2020-07-12    9278.308571
# 2020-07-19    9192.110714
# 2020-07-26    9177.447500
# Freq: W-SUN, Name: weighted_price, Length: 216, dtype: float64

# %%
plt.plot(ts_week)

# %%
# check for stationarity

def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean = timeseries.rolling(window=5,center=False).mean() 
    rolstd = timeseries.rolling(window=5,center=False).std()

    #Plot rolling statistics:
    orig = plt.plot(timeseries, color='green',label='Bitcoin Data')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.xlabel('Time(Days)',fontsize=24)
    plt.ylabel('$(Dollar)',fontsize=24)
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
test_stationarity(ts_week)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.028658
# p-value                          0.274151
# #Lags Used                      10.000000
# Number of Observations Used    205.000000
# Critical Value (1%)             -3.462658
# Critical Value (5%)             -2.875744
# Critical Value (10%)            -2.574341
# dtype: float64

# %% [markdown]
# Because the test statistic is more than the 5% critical value and the p-value is larger than 0.05, the moving average is not constant over time and the null hypothesis of the Dickey-Fuller test cannot be rejected. This shows that the weekly time series is not stationary.
# Before you can apply ARIMA models for forecasting, you need to transform this time series into a stationary time series.

# %%
# apply a non linear log transform

ts_week_log = np.log(ts_week)

# %%
test_stationarity(ts_week_log)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.590068
# p-value                          0.488581
# #Lags Used                       1.000000
# Number of Observations Used    214.000000
# Critical Value (1%)             -3.461282
# Critical Value (5%)             -2.875143
# Critical Value (10%)            -2.574020
# dtype: float64

# %% [markdown]
# The Dickey-Fuller test results confirm that the series is still non-stationary. Again the test statistic is larger than the 5% critical value and the p-value larger than 0.05.

# %%
# remove trend and seasonality with decomposition

decomposition = seasonal_decompose(ts_week)

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(411)
plt.plot(ts_week_log[-80:], label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend[-80:], label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal[-80:],label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual[-80:], label='Residuals')
plt.legend(loc='best')
plt.tight_layout()

# %%
# remove trend and seasonality with differencing

ts_week_log_diff = ts_week_log - ts_week_log.shift()
plt.plot(ts_week_log_diff,color='green')
plt.xlabel('Time(Days)',fontsize=24)
plt.title('Seasonality',fontsize=24)
# Out:
# Text(0.5, 1.0, 'Seasonality')

# %%
ts_week_log_diff.dropna(inplace=True)
test_stationarity(ts_week_log_diff)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.032397e+01
# p-value                        2.958815e-18
# #Lags Used                     0.000000e+00
# Number of Observations Used    2.140000e+02
# Critical Value (1%)           -3.461282e+00
# Critical Value (5%)           -2.875143e+00
# Critical Value (10%)          -2.574020e+00
# dtype: float64

# %%
from matplotlib import pyplot
from statsmodels.graphics.tsaplots import plot_acf
series = ts_week_log_diff
plot_acf(series)
pyplot.show()

# %%
from statsmodels.graphics.tsaplots import plot_pacf
series = ts_week_log_diff
plot_pacf(series, lags=25)
pyplot.show()

# %%
size = int(len(ts_week_log)*(0.7))
train, test = ts_week_log[0:size], ts_week_log[size:len(ts_week_log)]
history = [x for x in train]
predictions = list()

print('Printing Predicted vs Expected Values...')
print('\n')
for t in range(len(test)):
    model = ARIMA(history, order=(2,1,2))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(float(yhat))
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (np.exp(yhat), np.exp(obs)))

error = mean_squared_error(test, predictions)
r2 = r2_score(test, predictions)
mae = mean_absolute_error(test, predictions)

print('\n')
print('Printing Mean Squared Error of Predictions...')
print('Test MSE: %.6f' % error)
print('Test R2: %.6f' % r2)
print('Test MAE: %.6f' % mae)
# Out:
# Printing Predicted vs Expected Values...
#
#
# predicted=5389.816802, expected=5513.791429
# predicted=5547.161037, expected=6258.173929
# predicted=6749.885526, expected=7716.203929
# predicted=8292.499784, expected=7977.578571
# predicted=8266.195085, expected=8606.374286
# predicted=9118.096146, expected=7911.675000
# predicted=7823.314452, expected=8316.171786
# predicted=8646.400224, expected=9746.684286
# predicted=10411.057713, expected=11684.696429
# predicted=12602.767695, expected=11117.936786
# predicted=11442.028282, expected=11727.769286
# predicted=11950.766308, expected=10307.138571
# predicted=9842.702785, expected=9875.768571
# predicted=9801.954615, expected=10172.221429
# predicted=10503.060467, expected=11659.199286
# predicted=12401.219917, expected=10548.963571
# predicted=10182.009858, expected=10357.297143
# predicted=10606.541202, expected=9845.809643
# predicted=9572.677067, expected=10452.787857
# predicted=11015.595698, expected=10275.543571
# predicted=10198.328656, expected=10155.172143
# predicted=10207.466456, expected=8574.633214
# predicted=8453.324457, expected=8206.353929
# predicted=8022.272004, expected=8343.560357
# predicted=8654.132651, expected=8121.791786
# predicted=7880.915519, expected=8334.645000
# predicted=8701.699424, expected=9287.417857
# predicted=9569.131033, expected=9148.121071
# predicted=9227.139842, expected=8668.402500
# predicted=8652.648685, expected=7742.253571
# predicted=7507.687720, expected=7392.373571
# predicted=7514.684511, expected=7412.540357
# predicted=7351.547195, expected=7243.436429
# predicted=7365.380261, expected=7092.797857
# predicted=7070.997229, expected=7301.291429
# predicted=7435.054702, expected=7243.681071
# predicted=7322.105794, expected=7968.160000
# predicted=8255.797983, expected=8666.869286
# predicted=9086.946809, expected=8532.810000
# predicted=8434.390102, expected=9247.694643
# predicted=9755.362399, expected=9619.990357
# predicted=9725.156597, expected=10132.835357
# predicted=10437.670556, expected=9758.486429
# predicted=9759.704489, expected=9006.903929
# predicted=8727.208532, expected=8846.255000
# predicted=9076.334300, expected=6582.570357
# predicted=5967.657107, expected=5698.951071
# predicted=5331.220980, expected=6450.088214
# predicted=6834.542109, expected=6625.920714
# predicted=6622.080507, expected=7115.002857
# predicted=7455.786256, expected=6963.985000
# predicted=6923.080828, expected=7266.350000
# predicted=7453.449342, expected=8465.678929
# predicted=9012.974381, expected=9296.798214
# predicted=9606.026654, expected=9219.713571
# predicted=9323.776946, expected=9364.010357
# predicted=9439.012226, expected=9239.754286
# predicted=9342.413354, expected=9710.683214
# predicted=9906.473517, expected=9588.985357
# predicted=9683.085292, expected=9371.440000
# predicted=9302.523489, expected=9304.762143
# predicted=9465.727716, expected=9128.255000
# predicted=9053.930062, expected=9278.308571
# predicted=9504.019736, expected=9192.110714
# predicted=9176.522809, expected=9177.447500
#
#
# Printing Mean Squared Error of Predictions...
# Test MSE: 0.007149
# Test R2: 0.742833
# Test MAE: 0.063747

# %%
predictions_series = pd.Series(predictions, index = test.index)

# %%
fig, ax = plt.subplots()
ax.set(title='Prediction (ARIMA)', xlabel='Date', ylabel='$(Dollar)')
ax.plot(ts_week[-65:], 'b', label='observed')
ax.plot(np.exp(predictions_series), 'g', label='rolling one-step out-of-sample forecast')
legend = ax.legend(loc='upper left')
legend.get_frame().set_facecolor('w')
